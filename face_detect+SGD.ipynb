# %%
import warnings
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt

from keras.models import Model
from keras.layers import Flatten, Dense, Input, Conv2D, MaxPooling2D,Dropout, BatchNormalization, Activation
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D,AveragePooling2D
from keras.engine.topology import get_source_inputs
from keras.utils import layer_utils, to_categorical
from keras import backend as K
from keras import optimizers
# Out:
# Using TensorFlow backend.
# /home/pirl/anaconda3/envs/vnect/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/pirl/anaconda3/envs/vnect/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/pirl/anaconda3/envs/vnect/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/pirl/anaconda3/envs/vnect/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/pirl/anaconda3/envs/vnect/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/pirl/anaconda3/envs/vnect/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# load dataset list

train_data = pd.read_csv("train_vision.csv")
train_filename = train_data["filename"].values.tolist()
train_data["label"] = train_data["label"] -1
train_label = train_data["label"].values.tolist()

test_data = pd.read_csv("test_vision.csv")
test_filename = test_data["filename"].values.tolist()

print(len(train_filename), len(train_label), len(test_filename))
# Out:
# 5850 5850 2000

# %%
# load train data
input_height , input_width = 128, 128
n_class = 6

def getImageArr(img_name):
        img = cv2.imread("faces_images/" + img_name, 1)
        img = np.float32(img) / 127.5 - 1   #0~255 를 평균 0이게 수정
        return img

X = []
for name in train_filename:
    X.append(getImageArr(name))
    
X, Y = np.array(X), to_categorical(np.array(train_label),n_class)
print(X.shape, Y.shape)
# Out:
# (5850, 128, 128, 3) (5850, 6)

# %%
# split dataset

train_rate = 0.85
index_train = np.random.choice(X.shape[0],int(X.shape[0]*train_rate),replace=False)
index_test  = list(set(range(X.shape[0])) - set(index_train))
                            
# X, Y = shuffle(X,Y)
X_train, y_train = X[index_train],Y[index_train]
X_test, y_test = X[index_test],Y[index_test]
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (4972, 128, 128, 3) (4972, 6)
# (878, 128, 128, 3) (878, 6)

# %%
# load test data

real_test = []
for name in test_filename:
    real_test.append(getImageArr(name))
    
real_test = np.array(real_test)
print(real_test.shape)
# Out:
# (2000, 128, 128, 3)

# %%
 def nn_base(nClasses, input_height=128, input_width=128):
        
    img_input = Input(shape=(input_height,input_width, 3))
        
    IMAGE_ORDERING =  "channels_last"
    
    x = Conv2D(filters=16, kernel_size=(7, 7), padding='same', name='image_array', data_format=IMAGE_ORDERING)(img_input)
    x = BatchNormalization()(x)
    x = Conv2D(filters=16, kernel_size=(7, 7), padding='same', data_format=IMAGE_ORDERING)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=(2, 2), padding='same', data_format=IMAGE_ORDERING)(x)
    x = Dropout(.5)(x)

    x = Conv2D(filters=32, kernel_size=(5, 5), padding='same', data_format=IMAGE_ORDERING)(x)
    x = BatchNormalization()(x)
    x = Conv2D(filters=32, kernel_size=(5, 5), padding='same', data_format=IMAGE_ORDERING)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=(2, 2), padding='same')(x)
    x = Dropout(.5)(x)

    x = Conv2D(filters=64, kernel_size=(3, 3), padding='same', data_format=IMAGE_ORDERING)(x)
    x = BatchNormalization()(x)
    x = Conv2D(filters=64, kernel_size=(3, 3), padding='same', data_format=IMAGE_ORDERING)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=(2, 2), padding='same', data_format=IMAGE_ORDERING)(x)
    x = Dropout(.5)(x)

    x = Conv2D(filters=128, kernel_size=(3, 3), padding='same', data_format=IMAGE_ORDERING)(x)
    x = BatchNormalization()(x)
    x = Conv2D(filters=128, kernel_size=(3, 3), padding='same', data_format=IMAGE_ORDERING)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=(2, 2), padding='same', data_format=IMAGE_ORDERING)(x)
    x = Dropout(.5)(x)

    x = Conv2D(filters=256, kernel_size=(3, 3), padding='same', data_format=IMAGE_ORDERING)(x)
    x = BatchNormalization()(x)
    x = Conv2D(filters=nClasses, kernel_size=(3, 3), padding='same', data_format=IMAGE_ORDERING)(x)
    x = GlobalAveragePooling2D(data_format=IMAGE_ORDERING)(x)
    x = Activation('softmax', name='predictions')(x)
    
    model = Model(img_input, x)
    
    return model

# %%
model = nn_base(nClasses  = n_class,  
             input_height = 128, 
             input_width  = 128)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 128, 128, 3)       0
# _________________________________________________________________
# image_array (Conv2D)         (None, 128, 128, 16)      2368
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 16)      64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      12560
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 128, 16)      64
# _________________________________________________________________
# activation_1 (Activation)    (None, 128, 128, 16)      0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 64, 64, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        12832
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 32)        25632
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 64, 32)        0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 6)           13830
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 6)                 0
# _________________________________________________________________
# predictions (Activation)     (None, 6)                 0
# =================================================================
# Total params: 642,198
# Trainable params: 640,726
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
with K.tf.device('/gpu:1'):
    adam = optimizers.Adam(lr=1E-2, decay=5**(-4))
    model.compile(loss='categorical_crossentropy',
                  optimizer=sgd,
                  metrics=['accuracy'])

    hist1 = model.fit(X_train,y_train,
                      validation_data=(X_test,y_test),
                      batch_size=32,epochs=20)
# Out:
# Train on 4972 samples, validate on 878 samples
# Epoch 1/20
# 4972/4972 [==============================] - 9s 2ms/step - loss: 0.3297 - acc: 0.8797 - val_loss: 0.3867 - val_acc: 0.8724
# Epoch 2/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3164 - acc: 0.8896 - val_loss: 0.3237 - val_acc: 0.8929
# Epoch 3/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3215 - acc: 0.8831 - val_loss: 0.3390 - val_acc: 0.8895
# Epoch 4/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3125 - acc: 0.8864 - val_loss: 0.3676 - val_acc: 0.8736
# Epoch 5/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3167 - acc: 0.8880 - val_loss: 0.3665 - val_acc: 0.8770
# Epoch 6/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3117 - acc: 0.8872 - val_loss: 0.3622 - val_acc: 0.8838
# Epoch 7/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3245 - acc: 0.8803 - val_loss: 0.4431 - val_acc: 0.8508
# Epoch 8/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3266 - acc: 0.8817 - val_loss: 0.3616 - val_acc: 0.8838
# Epoch 9/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3176 - acc: 0.8835 - val_loss: 0.3415 - val_acc: 0.8907
# Epoch 10/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3226 - acc: 0.8880 - val_loss: 0.3024 - val_acc: 0.8998
# Epoch 11/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3221 - acc: 0.8835 - val_loss: 0.3609 - val_acc: 0.8827
# Epoch 12/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3168 - acc: 0.8846 - val_loss: 0.3311 - val_acc: 0.8918
# Epoch 13/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3083 - acc: 0.8890 - val_loss: 0.3082 - val_acc: 0.8998
# Epoch 14/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3062 - acc: 0.8910 - val_loss: 0.3390 - val_acc: 0.8861
# Epoch 15/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3068 - acc: 0.8930 - val_loss: 0.3739 - val_acc: 0.8759
# Epoch 16/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.2965 - acc: 0.8930 - val_loss: 0.4295 - val_acc: 0.8588
# Epoch 17/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3123 - acc: 0.8870 - val_loss: 0.3296 - val_acc: 0.8952
# Epoch 18/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3081 - acc: 0.8870 - val_loss: 0.3384 - val_acc: 0.8850
# Epoch 19/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3120 - acc: 0.8920 - val_loss: 0.3358 - val_acc: 0.8861
# Epoch 20/20
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.3010 - acc: 0.8888 - val_loss: 0.3216 - val_acc: 0.8975

# %%
with K.tf.device('/gpu:1'):
    sgd = optimizers.SGD(lr=1E-2, decay=5**(-4), momentum=0.9, nesterov=True)
    model.compile(loss='categorical_crossentropy',
                  optimizer=sgd,
                  metrics=['accuracy'])

    hist1 = model.fit(X_train,y_train,
                      validation_data=(X_test,y_test),
                      batch_size=32,epochs=30)
# Out:
# Train on 4972 samples, validate on 878 samples
# Epoch 1/30
# 4972/4972 [==============================] - 9s 2ms/step - loss: 0.2821 - acc: 0.8966 - val_loss: 0.4440 - val_acc: 0.8702
# Epoch 2/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.2657 - acc: 0.9065 - val_loss: 0.4161 - val_acc: 0.8781
# Epoch 3/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.2573 - acc: 0.9083 - val_loss: 0.3642 - val_acc: 0.8850
# Epoch 4/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.2491 - acc: 0.9109 - val_loss: 0.3719 - val_acc: 0.8838
# Epoch 5/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.2314 - acc: 0.9143 - val_loss: 0.3213 - val_acc: 0.8975
# Epoch 6/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.2337 - acc: 0.9193 - val_loss: 0.3330 - val_acc: 0.9021
# Epoch 7/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.2155 - acc: 0.9260 - val_loss: 0.4348 - val_acc: 0.8804
# Epoch 8/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.2195 - acc: 0.9210 - val_loss: 0.3504 - val_acc: 0.9043
# Epoch 9/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.2138 - acc: 0.9228 - val_loss: 0.3555 - val_acc: 0.8952
# Epoch 10/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.2118 - acc: 0.9274 - val_loss: 0.3252 - val_acc: 0.8964
# Epoch 11/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.2027 - acc: 0.9272 - val_loss: 0.3319 - val_acc: 0.8986
# Epoch 12/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1950 - acc: 0.9312 - val_loss: 0.3274 - val_acc: 0.8998
# Epoch 13/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1882 - acc: 0.9332 - val_loss: 0.3395 - val_acc: 0.9009
# Epoch 14/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1990 - acc: 0.9286 - val_loss: 0.3795 - val_acc: 0.8872
# Epoch 15/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1810 - acc: 0.9354 - val_loss: 0.3878 - val_acc: 0.8907
# Epoch 16/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1848 - acc: 0.9362 - val_loss: 0.3755 - val_acc: 0.8941
# Epoch 17/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1833 - acc: 0.9374 - val_loss: 0.3222 - val_acc: 0.9043
# Epoch 18/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1816 - acc: 0.9360 - val_loss: 0.3291 - val_acc: 0.9021
# Epoch 19/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1834 - acc: 0.9328 - val_loss: 0.3636 - val_acc: 0.8941
# Epoch 20/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1735 - acc: 0.9377 - val_loss: 0.3725 - val_acc: 0.8861
# Epoch 21/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1758 - acc: 0.9401 - val_loss: 0.3821 - val_acc: 0.8941
# Epoch 22/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1869 - acc: 0.9330 - val_loss: 0.3155 - val_acc: 0.9089
# Epoch 23/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1768 - acc: 0.9332 - val_loss: 0.3367 - val_acc: 0.8986
# Epoch 24/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1730 - acc: 0.9389 - val_loss: 0.3338 - val_acc: 0.8998
# Epoch 25/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1726 - acc: 0.9370 - val_loss: 0.3347 - val_acc: 0.8964
# Epoch 26/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1717 - acc: 0.9366 - val_loss: 0.3277 - val_acc: 0.9021
# Epoch 27/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1629 - acc: 0.9437 - val_loss: 0.3173 - val_acc: 0.9009
# Epoch 28/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1706 - acc: 0.9372 - val_loss: 0.3355 - val_acc: 0.9032
# Epoch 29/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1588 - acc: 0.9429 - val_loss: 0.3251 - val_acc: 0.9021
# Epoch 30/30
# 4972/4972 [==============================] - 7s 1ms/step - loss: 0.1705 - acc: 0.9385 - val_loss: 0.3452 - val_acc: 0.8929

# %%
for key in ['loss', 'val_loss']:
    plt.plot(hist1.history[key],label=key)
plt.legend()
plt.show()

# %%
y_pred = model.predict(real_test)
y_predi = np.argmax(y_pred,axis = 1) + 1
print(np.unique(y_predi), y_predi.shape)
# Out:
# [1 2 3 4 5 6] (2000,)

# %%
answer = pd.DataFrame({"prediction":y_predi})

# %%
answer.to_csv('results/3-5.csv',index=False, header="label")

# %%
a = pd.read_csv('1-1.csv').reset_index()
b = pd.read_csv('test_vision.csv').reset_index()
c = pd.merge(a,b, on='index')
c[:50]
# Out:
#     index  prediction       filename
# 0       0           1  face_2624.png
# 1       1           1  face_3385.png
# 2       2           1  face_5015.png
# 3       3           1  face_6715.png
# 4       4           4  face_6171.png
# 5       5           4  face_3269.png
# 6       6           4  face_4942.png
# 7       7           5  face_1095.png
# 8       8           4  face_7721.png
# 9       9           1  face_2455.png
# 10     10           4  face_6595.png
# 11     11           5  face_2024.png
# 12     12           4  face_1232.png
# 13     13           2  face_3796.png
# 14     14           4  face_4859.png
# 15     15           4    face_67.png
# 16     16           4  face_5667.png
# 17     17           1  face_2672.png
# 18     18           1  face_6755.png
# 19     19           1  face_5293.png
# 20     20           1  face_3996.png
# 21     21           4  face_7237.png
# 22     22           4   face_925.png
# 23     23           4   face_566.png
# 24     24           4  face_2910.png
# 25     25           5   face_266.png
# 26     26           4   face_611.png
# 27     27           4  face_5727.png
# 28     28           1  face_5443.png
# 29     29           1  face_5894.png
# 30     30           4  face_7963.png
# 31     31           1  face_5595.png
# 32     32           4  face_6896.png
# 33     33           4  face_3918.png
# 34     34           2  face_5286.png
# 35     35           2  face_2544.png
# 36     36           1  face_6850.png
# 37     37           4  face_4607.png
# 38     38           2  face_5386.png
# 39     39           6  face_7531.png
# 40     40           3  face_1924.png
# 41     41           4  face_4330.png
# 42     42           4   face_645.png
# 43     43           1  face_6040.png
# 44     44           1  face_4227.png
# 45     45           1  face_6876.png
# 46     46           4  face_4592.png
# 47     47           6  face_1092.png
# 48     48           3  face_2042.png
# 49     49           1  face_2531.png
